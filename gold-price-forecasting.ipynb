# %% [markdown]
# ## Importing Needed Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Reading The Data

# %%
data_dir = '../input/learn-time-series-forecasting-from-gold-price/gold_price_data.csv'
df = pd.read_csv(data_dir)

# %% [markdown]
# ## Data Exploration

# %%
df.head()
# Out:
#          Date  Value
# 0  1970-01-01   35.2
# 1  1970-04-01   35.1
# 2  1970-07-01   35.4
# 3  1970-10-01   36.2
# 4  1971-01-01   37.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10787 entries, 0 to 10786
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    10787 non-null  object
#  1   Value   10787 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 168.7+ KB

# %%
df.describe()
# Out:
#               Value
# count  10787.000000
# mean     653.596634
# std      434.030848
# min       35.100000
# 25%      349.200000
# 50%      409.350000
# 75%     1061.625000
# max     1895.000000

# %% [markdown]
# ### Set Date column as an index

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace= True)

# %%
plt.figure(figsize=(15, 6))
df['Value'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Gold Price")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Choosing Prediction Column

# %%
n_cols = 1
dataset = df["Value"]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (10787, 1)

# %% [markdown]
# ### Normalizing Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %% [markdown]
# ### Splitting the Data

# %%
# 75% to Train , 25% to Test
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 8090 Test Size : 2697

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (8090, 1)

# %% [markdown]
# ### Creating training set

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 100
n_cols = 1

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[5.37663315e-05],
#        [0.00000000e+00],
#        [1.61298995e-04],
#        [5.91429647e-04],
#        [1.23662563e-03],
#        [2.04312060e-03],
#        [2.68831658e-03],
#        [3.70987688e-03],
#        [4.51637185e-03],
#        [7.09715576e-03],
#        [1.45169095e-02],
#        [1.63449648e-02],
#        [1.54847035e-02],
#        [2.65068014e-02],
#        [4.57013818e-02],
#        [3.65073391e-02],
#        [3.84966934e-02],
#        [7.16705199e-02],
#        [6.39819345e-02],
#        [6.27453089e-02],
#        [8.00043013e-02],
#        [7.64557234e-02],
#        [7.06489596e-02],
#        [5.82827034e-02],
#        [5.65621808e-02],
#        [5.05941180e-02],
#        [4.72068391e-02],
#        [4.34969622e-02],
#        [5.34437335e-02],
#        [6.08634873e-02],
#        [5.77988064e-02],
#        [6.47346632e-02],
#        [6.98424646e-02],
#        [7.97354696e-02],
#        [7.96817033e-02],
#        [9.78547234e-02],
#        [1.02639927e-01],
#        [1.02639927e-01],
#        [1.03070058e-01],
#        [9.86612183e-02],
#        [1.01107586e-01],
#        [1.02371095e-01],
#        [1.01080703e-01],
#        [1.01564600e-01],
#        [9.97903113e-02],
#        [9.97634281e-02],
#        [9.81235550e-02],
#        [9.77203075e-02],
#        [9.97634281e-02],
#        [1.03312006e-01],
#        [1.05731491e-01],
#        [1.05086295e-01],
#        [1.07478897e-01],
#        [1.04790580e-01],
#        [1.08070326e-01],
#        [1.06860584e-01],
#        [1.07720845e-01],
#        [1.07586429e-01],
#        [1.06672402e-01],
#        [1.06779934e-01],
#        [1.04441099e-01],
#        [1.04951879e-01],
#        [1.11833970e-01],
#        [1.12586698e-01],
#        [1.16404108e-01],
#        [1.15812678e-01],
#        [1.13796441e-01],
#        [1.12452282e-01],
#        [1.10489811e-01],
#        [1.10516694e-01],
#        [1.14334104e-01],
#        [1.13957740e-01],
#        [1.14522286e-01],
#        [1.13930856e-01],
#        [1.15947094e-01],
#        [1.16807355e-01],
#        [1.16081510e-01],
#        [1.14791118e-01],
#        [1.14414753e-01],
#        [1.16242809e-01],
#        [1.14898650e-01],
#        [1.14468520e-01],
#        [1.09172536e-01],
#        [1.10032797e-01],
#        [1.11376956e-01],
#        [1.09737083e-01],
#        [1.10704877e-01],
#        [1.10167213e-01],
#        [1.09683316e-01],
#        [1.09898382e-01],
#        [1.10220980e-01],
#        [1.12317867e-01],
#        [1.11376956e-01],
#        [1.11296306e-01],
#        [1.10113447e-01],
#        [1.11699554e-01],
#        [1.11511372e-01],
#        [1.12989946e-01],
#        [1.12506049e-01],
#        [1.12532932e-01]])]
# y_train: [array([0.11097371])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((7990, 100, 1), (7990, 1))

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# ### Model Dtructure

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
# Fitting the LSTM to the Training set
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 37s 134ms/step - loss: 7.8321e-04 - mean_absolute_error: 0.0115
# Epoch 2/100
# 250/250 [==============================] - 33s 130ms/step - loss: 7.9435e-05 - mean_absolute_error: 0.0057
# Epoch 3/100
# 250/250 [==============================] - 33s 131ms/step - loss: 6.9315e-05 - mean_absolute_error: 0.0053
# Epoch 4/100
# 250/250 [==============================] - 32s 129ms/step - loss: 6.3067e-05 - mean_absolute_error: 0.0051
# Epoch 5/100
# 250/250 [==============================] - 34s 137ms/step - loss: 6.0918e-05 - mean_absolute_error: 0.0051
# Epoch 6/100
# 250/250 [==============================] - 33s 130ms/step - loss: 4.8732e-05 - mean_absolute_error: 0.0045
# Epoch 7/100
# 250/250 [==============================] - 35s 138ms/step - loss: 4.5710e-05 - mean_absolute_error: 0.0044
# Epoch 8/100
# 250/250 [==============================] - 35s 140ms/step - loss: 4.3076e-05 - mean_absolute_error: 0.0042
# Epoch 9/100
# 250/250 [==============================] - 35s 142ms/step - loss: 4.3015e-05 - mean_absolute_error: 0.0044
# Epoch 10/100
# 250/250 [==============================] - 35s 142ms/step - loss: 3.9030e-05 - mean_absolute_error: 0.0041
# Epoch 11/100
# 250/250 [==============================] - 35s 140ms/step - loss: 3.8537e-05 - mean_absolute_error: 0.0041
# Epoch 12/100
# 250/250 [==============================] - 33s 134ms/step - loss: 3.8858e-05 - mean_absolute_error: 0.0041
# Epoch 13/100
# 250/250 [==============================] - 32s 129ms/step - loss: 3.2327e-05 - mean_absolute_error: 0.0038
# Epoch 14/100
# 250/250 [==============================] - 34s 134ms/step - loss: 3.8640e-05 - mean_absolute_error: 0.0042
# Epoch 15/100
# 250/250 [==============================] - 33s 132ms/step - loss: 2.7472e-05 - mean_absolute_error: 0.0035
# Epoch 16/100
# 250/250 [==============================] - 35s 139ms/step - loss: 2.9492e-05 - mean_absolute_error: 0.0037
# Epoch 17/100
# 250/250 [==============================] - 36s 143ms/step - loss: 2.2493e-05 - mean_absolute_error: 0.0031
# Epoch 18/100
# 250/250 [==============================] - 35s 140ms/step - loss: 2.1977e-05 - mean_absolute_error: 0.0030
# Epoch 19/100
# 250/250 [==============================] - 34s 135ms/step - loss: 2.5166e-05 - mean_absolute_error: 0.0034
# Epoch 20/100
# 250/250 [==============================] - 33s 131ms/step - loss: 2.2437e-05 - mean_absolute_error: 0.0031
# Epoch 21/100
# 250/250 [==============================] - 33s 130ms/step - loss: 2.1125e-05 - mean_absolute_error: 0.0031
# Epoch 22/100
# 250/250 [==============================] - 32s 129ms/step - loss: 2.3688e-05 - mean_absolute_error: 0.0034
# Epoch 23/100
# 250/250 [==============================] - 35s 140ms/step - loss: 2.2707e-05 - mean_absolute_error: 0.0032
# Epoch 24/100
# 250/250 [==============================] - 37s 149ms/step - loss: 2.1801e-05 - mean_absolute_error: 0.0032
# Epoch 25/100
# 250/250 [==============================] - 35s 139ms/step - loss: 1.9573e-05 - mean_absolute_error: 0.0029
# Epoch 26/100
# 250/250 [==============================] - 34s 137ms/step - loss: 1.9908e-05 - mean_absolute_error: 0.0030
# Epoch 27/100
# 250/250 [==============================] - 33s 132ms/step - loss: 2.2839e-05 - mean_absolute_error: 0.0033
# Epoch 28/100
# 250/250 [==============================] - 32s 130ms/step - loss: 2.0932e-05 - mean_absolute_error: 0.0031
# Epoch 29/100
# 250/250 [==============================] - 32s 128ms/step - loss: 1.8781e-05 - mean_absolute_error: 0.0029
# Epoch 30/100
# 250/250 [==============================] - 33s 130ms/step - loss: 1.8137e-05 - mean_absolute_error: 0.0028
# Epoch 31/100
# 250/250 [==============================] - 33s 132ms/step - loss: 1.8715e-05 - mean_absolute_error: 0.0029
# Epoch 32/100
# 250/250 [==============================] - 32s 129ms/step - loss: 1.9240e-05 - mean_absolute_error: 0.0029
# Epoch 33/100
# 250/250 [==============================] - 34s 136ms/step - loss: 1.8733e-05 - mean_absolute_error: 0.0029
# Epoch 34/100
# 250/250 [==============================] - 33s 132ms/step - loss: 1.9726e-05 - mean_absolute_error: 0.0030
# Epoch 35/100
# 250/250 [==============================] - 33s 130ms/step - loss: 2.0820e-05 - mean_absolute_error: 0.0031
# Epoch 36/100
# 250/250 [==============================] - 34s 135ms/step - loss: 1.9846e-05 - mean_absolute_error: 0.0030
# Epoch 37/100
# 250/250 [==============================] - 33s 133ms/step - loss: 1.8678e-05 - mean_absolute_error: 0.0028
# Epoch 38/100
# 250/250 [==============================] - 33s 134ms/step - loss: 1.9960e-05 - mean_absolute_error: 0.0030
# Epoch 39/100
# 250/250 [==============================] - 34s 136ms/step - loss: 1.7783e-05 - mean_absolute_error: 0.0027
# Epoch 40/100
# 250/250 [==============================] - 35s 140ms/step - loss: 2.2246e-05 - mean_absolute_error: 0.0033
# Epoch 41/100
# 250/250 [==============================] - 33s 132ms/step - loss: 1.8837e-05 - mean_absolute_error: 0.0029
# Epoch 42/100
# 250/250 [==============================] - 34s 136ms/step - loss: 1.8298e-05 - mean_absolute_error: 0.0027
# Epoch 43/100
# 250/250 [==============================] - 34s 138ms/step - loss: 1.7451e-05 - mean_absolute_error: 0.0027
# Epoch 44/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.9801e-05 - mean_absolute_error: 0.0030
# Epoch 45/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.8750e-05 - mean_absolute_error: 0.0029
# Epoch 46/100
# 250/250 [==============================] - 35s 141ms/step - loss: 2.0061e-05 - mean_absolute_error: 0.0030
# Epoch 47/100
# 250/250 [==============================] - 35s 138ms/step - loss: 1.9033e-05 - mean_absolute_error: 0.0028
# Epoch 48/100
# 250/250 [==============================] - 34s 138ms/step - loss: 1.6989e-05 - mean_absolute_error: 0.0026
# Epoch 49/100
# 250/250 [==============================] - 34s 136ms/step - loss: 2.1037e-05 - mean_absolute_error: 0.0031
# Epoch 50/100
# 250/250 [==============================] - 34s 134ms/step - loss: 1.6556e-05 - mean_absolute_error: 0.0026
# Epoch 51/100
# 250/250 [==============================] - 35s 140ms/step - loss: 1.7710e-05 - mean_absolute_error: 0.0027
# Epoch 52/100
# 250/250 [==============================] - 34s 137ms/step - loss: 1.7156e-05 - mean_absolute_error: 0.0026
# Epoch 53/100
# 250/250 [==============================] - 33s 132ms/step - loss: 1.6647e-05 - mean_absolute_error: 0.0025
# Epoch 54/100
# 250/250 [==============================] - 35s 140ms/step - loss: 1.6962e-05 - mean_absolute_error: 0.0027
# Epoch 55/100
# 250/250 [==============================] - 33s 131ms/step - loss: 1.7549e-05 - mean_absolute_error: 0.0027
# Epoch 56/100
# 250/250 [==============================] - 32s 130ms/step - loss: 1.7630e-05 - mean_absolute_error: 0.0027
# Epoch 57/100
# 250/250 [==============================] - 32s 130ms/step - loss: 1.9094e-05 - mean_absolute_error: 0.0029
# Epoch 58/100
# 250/250 [==============================] - 33s 132ms/step - loss: 1.9326e-05 - mean_absolute_error: 0.0029
# Epoch 59/100
# 250/250 [==============================] - 34s 134ms/step - loss: 1.5906e-05 - mean_absolute_error: 0.0025
# Epoch 60/100
# 250/250 [==============================] - 33s 134ms/step - loss: 1.8061e-05 - mean_absolute_error: 0.0028
# Epoch 61/100
# 250/250 [==============================] - 35s 140ms/step - loss: 1.8306e-05 - mean_absolute_error: 0.0028
# Epoch 62/100
# 250/250 [==============================] - 33s 133ms/step - loss: 1.6724e-05 - mean_absolute_error: 0.0026
# Epoch 63/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.7649e-05 - mean_absolute_error: 0.0027
# Epoch 64/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.7206e-05 - mean_absolute_error: 0.0026
# Epoch 65/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.7839e-05 - mean_absolute_error: 0.0028
# Epoch 66/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.8841e-05 - mean_absolute_error: 0.0029
# Epoch 67/100
# 250/250 [==============================] - 37s 146ms/step - loss: 1.6020e-05 - mean_absolute_error: 0.0025
# Epoch 68/100
# 250/250 [==============================] - 37s 149ms/step - loss: 1.6300e-05 - mean_absolute_error: 0.0025
# Epoch 69/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.7304e-05 - mean_absolute_error: 0.0027
# Epoch 70/100
# 250/250 [==============================] - 36s 144ms/step - loss: 1.7530e-05 - mean_absolute_error: 0.0027
# Epoch 71/100
# 250/250 [==============================] - 35s 141ms/step - loss: 2.0013e-05 - mean_absolute_error: 0.0030
# Epoch 72/100
# 250/250 [==============================] - 35s 139ms/step - loss: 1.6854e-05 - mean_absolute_error: 0.0026
# Epoch 73/100
# 250/250 [==============================] - 35s 138ms/step - loss: 1.9366e-05 - mean_absolute_error: 0.0029
# Epoch 74/100
# 250/250 [==============================] - 34s 136ms/step - loss: 1.5567e-05 - mean_absolute_error: 0.0024
# Epoch 75/100
# 250/250 [==============================] - 34s 138ms/step - loss: 1.7008e-05 - mean_absolute_error: 0.0026
# Epoch 76/100
# 250/250 [==============================] - 34s 135ms/step - loss: 1.7088e-05 - mean_absolute_error: 0.0026
# Epoch 77/100
# 250/250 [==============================] - 35s 139ms/step - loss: 1.8175e-05 - mean_absolute_error: 0.0028
# Epoch 78/100
# 250/250 [==============================] - 37s 148ms/step - loss: 1.7967e-05 - mean_absolute_error: 0.0028
# Epoch 79/100
# 250/250 [==============================] - 38s 150ms/step - loss: 1.6765e-05 - mean_absolute_error: 0.0026
# Epoch 80/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.7410e-05 - mean_absolute_error: 0.0027
# Epoch 81/100
# 250/250 [==============================] - 35s 141ms/step - loss: 1.6512e-05 - mean_absolute_error: 0.0026
# Epoch 82/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.6830e-05 - mean_absolute_error: 0.0026
# Epoch 83/100
# 250/250 [==============================] - 35s 140ms/step - loss: 1.7286e-05 - mean_absolute_error: 0.0026
# Epoch 84/100
# 250/250 [==============================] - 34s 136ms/step - loss: 1.9918e-05 - mean_absolute_error: 0.0029
# Epoch 85/100
# 250/250 [==============================] - 34s 138ms/step - loss: 1.7181e-05 - mean_absolute_error: 0.0026
# Epoch 86/100
# 250/250 [==============================] - 35s 141ms/step - loss: 1.5777e-05 - mean_absolute_error: 0.0025
# Epoch 87/100
# 250/250 [==============================] - 36s 142ms/step - loss: 1.7861e-05 - mean_absolute_error: 0.0028
# Epoch 88/100
# 250/250 [==============================] - 36s 145ms/step - loss: 1.8251e-05 - mean_absolute_error: 0.0028
# Epoch 89/100
# 250/250 [==============================] - 35s 141ms/step - loss: 1.8133e-05 - mean_absolute_error: 0.0028
# Epoch 90/100
# 250/250 [==============================] - 35s 138ms/step - loss: 1.7198e-05 - mean_absolute_error: 0.0027
# Epoch 91/100
# 250/250 [==============================] - 34s 138ms/step - loss: 1.6035e-05 - mean_absolute_error: 0.0025
# Epoch 92/100
# 250/250 [==============================] - 34s 138ms/step - loss: 1.8330e-05 - mean_absolute_error: 0.0028
# Epoch 93/100
# 250/250 [==============================] - 34s 137ms/step - loss: 1.7145e-05 - mean_absolute_error: 0.0026
# Epoch 94/100
# 250/250 [==============================] - 36s 146ms/step - loss: 1.6623e-05 - mean_absolute_error: 0.0026
# Epoch 95/100
# 250/250 [==============================] - 36s 143ms/step - loss: 1.8986e-05 - mean_absolute_error: 0.0029
# Epoch 96/100
# 250/250 [==============================] - 35s 139ms/step - loss: 1.5738e-05 - mean_absolute_error: 0.0025
# Epoch 97/100
# 250/250 [==============================] - 35s 139ms/step - loss: 1.8566e-05 - mean_absolute_error: 0.0029
# Epoch 98/100
# 250/250 [==============================] - 33s 133ms/step - loss: 1.7148e-05 - mean_absolute_error: 0.0026
# Epoch 99/100
# 250/250 [==============================] - 34s 137ms/step - loss: 1.5876e-05 - mean_absolute_error: 0.0024
# Epoch 100/100
# 250/250 [==============================] - 33s 132ms/step - loss: 1.6776e-05 - mean_absolute_error: 0.0026

# %% [markdown]
# ### Model Evaluation

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Predection

# %% [markdown]
# ### Creating testing set

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((2697, 60, 1), (2697, 1))

# %%
# Get Prediction
predictions = model.predict(x_test)

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (2697, 1)

# %% [markdown]
# ### Root mean square error

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 40.93

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#       Predictions  Actuals
# 0     1093.395996  1114.75
# 1     1091.558838  1104.00
# 2     1081.907593  1130.00
# 3     1108.578369  1134.75
# 4     1111.629761  1149.00
# ...           ...      ...
# 2692  1614.895386  1672.50
# 2693  1596.515503  1655.70
# 2694  1579.497192  1653.75
# 2695  1576.805176  1570.70
# 2696  1491.240479  1562.80
#
# [2697 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %% [markdown]
# ### Visualize Predictions with The Data
# for one feature

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Gold Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Gold Price', fontsize= 18)
plt.plot(train['Value'], linewidth= 3)
plt.plot(test['Value'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
